# %%
import pandas as pd

# %%
data = pd.read_csv("static/scrapper_data.csv")

# %%
dataframe = pd.DataFrame(data)

# %%
dataframe
# Out:
#     Unnamed: 0                       _id  \
# 0            0  60478d3029b0228eb82583ac
# 1            1  60478d3029b0228eb82583ae
# 2            2  60478d3129b0228eb82583b0
# 3            3  60478d3129b0228eb82583b2
# 4            4  60478d3129b0228eb82583b4
# 5            5  60478d3129b0228eb82583b6
# 6            6  60478d3129b0228eb82583b8
# 7            7  60478d3229b0228eb82583ba
# 8            8  60478d3229b0228eb82583bc
# 9            9  60478d3229b0228eb82583be
# 10          10  60478d3429b0228eb82583c0
# 11          11  60478d9f12a9486967b21291
# 12          12  60478d9f12a9486967b21293
# 13          13  60478d9f12a9486967b21295
# 14          14  604793d6c096c290e8a6c9da
# 15          15  604793d6c096c290e8a6c9dc
# 16          16  604793d8c096c290e8a6c9de
# 17          17  604793d8c096c290e8a6c9e0
# 18          18  604793dfc096c290e8a6c9eb
# 19          19  604793dfc096c290e8a6c9ed
# 20          20  604793dfc096c290e8a6c9ef
# 21          21  604793e0c096c290e8a6c9f1
# ...

# %%
import matplotlib.pyplot as plt

# %%
img = plt.hist(x='rating').get_figure()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-31-ed3a10ab679b> in <module>
# ----> 1 img = plt.hist(x='rating').get_figure()
#
# AttributeError: 'tuple' object has no attribute 'get_figure'

# %%
plt.savefig(img, "static/img.png")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-21-aa1785b295d3> in <module>
# ----> 1 plt.savefig(img, "static/img.png")
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\pyplot.py in savefig(*args, **kwargs)
#     721 def savefig(*args, **kwargs):
#     722     fig = gcf()
# --> 723     res = fig.savefig(*args, **kwargs)
#     724     fig.canvas.draw_idle()   # need this if 'transparent=True' to reset colors
#     725     return res
#
# TypeError: savefig() takes 2 positional arguments but 3 were given

# %%
plt.plot(dataframe)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axis.py in convert_units(self, x)
#    1572         try:
# -> 1573             ret = self.converter.convert(x, self.units, self)
#    1574         except Exception as e:
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\category.py in convert(value, unit, axis)
#      48         if unit is None:
# ---> 49             raise ValueError(
#      50                 'Missing category information for StrCategoryConverter; '
#
# ValueError: Missing category information for StrCategoryConverter; this might be caused by unintendedly mixing categorical and numeric data
#
# The above exception was the direct cause of the following exception:
#
# ConversionError                           Traceback (most recent call last)
# <ipython-input-32-966b87ef8873> in <module>
# ...
